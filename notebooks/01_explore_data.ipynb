# %%
import pandas as pd
from pathlib import Path

# Load all association partitions
associations_dir = Path('../data/raw/direct_associations')
association_files = sorted(associations_dir.glob('*.parquet'))

# Read and concatenate all partitions
a_df = pd.concat([pd.read_parquet(f) for f in association_files], ignore_index=True)

# Load the biomarkers file
b_df = pd.read_parquet("../data/raw/evidence_cancer_biomarkers/evidence_cancer_biomarkers.parquet")

# %%
print(f"Loaded {len(association_files)} partitions")
print(f"Total rows: {a_df.shape[0]:,}")

a_df.head()
# Out:
# Loaded 20 partitions
# Total rows: 4,492,971
#       diseaseId         targetId     score  evidenceCount
# 0  DOID_0050890  ENSG00000001084  0.031799              4
# 1  DOID_0050890  ENSG00000002549  0.001478              1
# 2  DOID_0050890  ENSG00000004142  0.002217              1
# 3  DOID_0050890  ENSG00000004478  0.002217              1
# 4  DOID_0050890  ENSG00000004948  0.002957              1

# %%
b_df.head(50)
# Out:
#                                           id targetFromSourceId  \
# 0   0010fb8e532bdb5d0072cc5db9991923f3c4b121               EGFR
# 1   0023bc1ee01a34cf68f6e8d55e0b4466893114b8            SMARCB1
# 2   006c16ffc7eb3dc04bb2ccf3ce4994bb1990fc9d               EGFR
# 3   007f807da0c31088ec4a9136812edb6f70d87701                NF1
# 4   00b3e7749de158868d86a20a241ef3122f932137              ERCC1
# 5   0119fae7b3f606cce180328d0ad893706586429a             MAP2K1
# 6   01a588cbcd96623bb612b85abfc97e51b93bbaa0               EGFR
# 7   01a6a63ad25808fe0eee29dc7fdb1b50b54993bd              ERCC6
# 8   01edd01a0414afd50a9964a16f911dc36cdad84f                NF1
# 9   022396645475587dfd4d032e0673b7cec820369b              ZNRF3
# 10  022b5518f8bff136a13d089b306bfbaf60d39ef3               EGFR
# 11  026434a6ad26ace7ce8cb75ee8626448410e8c69                NF1
# 12  0274d4abad6155af725ec04ee2ef16b042831471               DPYD
# 13  02895720d3b2658d92af8292c6c14a0909e66c1c                NF1
# 14  028e3ffad33f8c185374da203f8d2fcf5bd2e3c8               ABL1
# 15  0301353b79d8f66acc7fcd10c197caa6bc894ca9                SMO
# 16  033cec7fc45b36431c48064ecd8f7f4f00d8a0c3              PALB2
# 17  037da9c2b79288b319df2aeb2985d9784c543eaa               JAK1
# 18  037e9690938a8ee05b17f9c96df2401ebe15e654              ERBB2
# 19  03b958d9f53bc50f7962c2c748d5f51a9f5f36ac               EGFR
# 20  040d213cad0dd2a387d513f05cfdf12e1fc1807f              GNA11
# 21  04389bc21fc5125398a124e5dcb35c5700e14495                MET
# 22  0468f245bbf7fecfc82c6eae334b8b1f7397d3c8               NRAS
# 23  04d05b28d6fdbb890a2ecc45bf5bc62050305632              ERBB2
# 24  05387e19c94e509ba679c4f20ab5443606be53ca                KIT
# 25  054dfbe2a634639e4d97e04aa617459c88acb4df               BRAF
# 26  055fa2f24d33504086d6081b9706188decac33e1                ATR
# 27  0576fff07da94fea5c370c68c4eb3a68d21e1bd5                NF2
# 28  060c69c248b552be559953e1873d8cea3380ba26               ABL1
# 29  068a71e2b184ce84f548e6c3f94b772f6bb7f25b                ALK
# 30  06a0d71fc6dd86bde04d897e89be57a56404970f                NF2
# 31  072ee1c871f79016315c983e8f4995490d5c08a3               HRAS
# 32  073bc85bbf0e542a4b72627224abfcfb10f1017e              PBRM1
# 33  075b37be7fcd3c9fe2c06e42a12a8fd5cca35b76               PAK1
# 34  0773e656248c4358c42d5ea003e7f96e38990410               ABL1
# 35  07b74b84f25244086ad9557129ed692e0acbe15b               TP53
# 36  07b9dc6dd75c0ab2ecf3106cf59ffa0973fc81c7               NRAS
# 37  083b88bebfe32a05e69f0db345c1fcef2d054206              CRLF2
# 38  08a20b866cd7d4d258dc2421b99ce641c991b51b               BRAF
# 39  08c5720b1197a1a56d3cb2d2665ad9c92b670fdb             PIK3CA
# 40  08f40e1371fcba9ebde9568f2dd672903d80feed               BAP1
# 41  08f91b7c77f82adc25a40960649c6561c1e3554b              BRCA1
# 42  0903d548495248e842e18f233f5d4ad9b6285fed               CDK4
# 43  09668ba4fdc2d4cf59015bef62efbad45bc1a137              AURKA
# 44  0990ed8d8b5fae9ece1c6436437d209c53e8573f               ABL1
# 45  09cbfdf92b11acffa3512e9e439c60c6e248fd82               ROS1
# 46  09d2e4332f159c7aa111cd99433152d44037fc3a             DNMT3A
# 47  09f5c420e6bbba58c4da18e1c73434f40bd653d7                NF2
# 48  0a00bc45253da0f5eb1ff437dca2ed21d480eb95                NF1
# 49  0a03f0cfe3d633f7be0752f72b7a6583d07c5d0b               KRAS
#
#    diseaseFromSourceMappedId       datasourceId        datatypeId  \
# 0                EFO_0003060  cancer_biomarkers  affected_pathway
# 1                EFO_0005701  cancer_biomarkers  affected_pathway
# 2                EFO_0000365  cancer_biomarkers  affected_pathway
# 3                EFO_0001071  cancer_biomarkers  affected_pathway
# 4                EFO_0001071  cancer_biomarkers  affected_pathway
# 5                EFO_0000365  cancer_biomarkers  affected_pathway
# 6                EFO_0005543  cancer_biomarkers  affected_pathway
# 7                EFO_0001075  cancer_biomarkers  affected_pathway
# 8                EFO_0000760  cancer_biomarkers  affected_pathway
# 9                EFO_0000365  cancer_biomarkers  affected_pathway
# 10               EFO_0001071  cancer_biomarkers  affected_pathway
# 11               EFO_0000658  cancer_biomarkers  affected_pathway
# 12               EFO_0000311  cancer_biomarkers  affected_pathway
# 13               EFO_0005543  cancer_biomarkers  affected_pathway
# 14               EFO_0000339  cancer_biomarkers  affected_pathway
# 15               EFO_0002939  cancer_biomarkers  affected_pathway
# 16               EFO_0002618  cancer_biomarkers  affected_pathway
# 17               EFO_0000220  cancer_biomarkers  affected_pathway
# 18               EFO_0000304  cancer_biomarkers  affected_pathway
# 19               EFO_0000365  cancer_biomarkers  affected_pathway
# 20               EFO_0000389  cancer_biomarkers  affected_pathway
# 21               EFO_0000365  cancer_biomarkers  affected_pathway
# 22               EFO_0000389  cancer_biomarkers  affected_pathway
# 23               EFO_0001071  cancer_biomarkers  affected_pathway
# 24               EFO_0000389  cancer_biomarkers  affected_pathway
# 25               EFO_0001075  cancer_biomarkers  affected_pathway
# 26               EFO_0000311  cancer_biomarkers  affected_pathway
# 27               EFO_0001071  cancer_biomarkers  affected_pathway
# 28               EFO_0000220  cancer_biomarkers  affected_pathway
# 29               EFO_0000365  cancer_biomarkers  affected_pathway
# 30             Orphanet_2495  cancer_biomarkers  affected_pathway
# 31               EFO_0000222  cancer_biomarkers  affected_pathway
# 32               EFO_0000311  cancer_biomarkers  affected_pathway
# 33               EFO_0000389  cancer_biomarkers  affected_pathway
# 34               EFO_0000339  cancer_biomarkers  affected_pathway
# 35               EFO_1000576  cancer_biomarkers  affected_pathway
# 36               EFO_0000389  cancer_biomarkers  affected_pathway
# 37               EFO_0000220  cancer_biomarkers  affected_pathway
# 38               EFO_1000318  cancer_biomarkers  affected_pathway
# 39               EFO_0000292  cancer_biomarkers  affected_pathway
# 40               EFO_0000389  cancer_biomarkers  affected_pathway
# 41               EFO_0001075  cancer_biomarkers  affected_pathway
# 42               EFO_0000574  cancer_biomarkers  affected_pathway
# 43               EFO_0000673  cancer_biomarkers  affected_pathway
# 44               EFO_0000339  cancer_biomarkers  affected_pathway
# 45               EFO_0000571  cancer_biomarkers  affected_pathway
# 46               EFO_0000222  cancer_biomarkers  affected_pathway
# 47               EFO_0000693  cancer_biomarkers  affected_pathway
# 48               EFO_0005543  cancer_biomarkers  affected_pathway
# 49               EFO_0001071  cancer_biomarkers  affected_pathway
#
#                        drugFromSource         drugId drugResponse  \
# 0             Egfr Inhibitor 1st Gens           None  EFO_0020001
# 1                     Ezh2 Inhibitors           None   GO_0042493
# 2                 Egfr Mab Inhibitors           None   GO_0042493
# 3                           Dasatinib  CHEMBL5416410  EFO_0020001
# 4                           Cisplatin    CHEMBL11359   GO_0042493
# 5                 Egfr Mab Inhibitors           None  EFO_0020001
# 6             Egfr Inhibitor 2nd Gens           None  EFO_0020002
# 7                           Cisplatin    CHEMBL11359   GO_0042493
# 8                     Aurk Inhibitors           None   GO_0042493
# 9                Porcupine Inhibitors           None   GO_0042493
# 10                          Erlotinib      CHEMBL553   GO_0042493
# 11                           Imatinib      CHEMBL941   GO_0042493
# 12                       Flourouracil           None  EFO_0020003
# 13                          Erlotinib      CHEMBL553  EFO_0020002
# 14                          Nilotinib   CHEMBL255863   GO_0042493
# 15                         Vismodegib   CHEMBL473417  EFO_0020001
# 16                        Mytomycin C           None   GO_0042493
# 17                        Ruxolitinib  CHEMBL1789941   GO_0042493
# 18                         Everolimus  CHEMBL1908360   GO_0042493
# 19                          Cetuximab  CHEMBL1201577  EFO_0020001
# 20                         Vorinostat       CHEMBL98   GO_0042493
# 21                    Bcl2 Inhibitors           None   GO_0042493
# 22                 Pan-raf Inhibitors           None   GO_0042493
# 23          Ado-trastuzumab Emtansine           None   GO_0042493
# 24                           Imatinib      CHEMBL941  EFO_0020002
# 25                    Braf Inhibitors           None   GO_0042493
# 26                           Olaparib   CHEMBL521686   GO_0042493
# 27                          Cetuximab  CHEMBL1201577  EFO_0020001
# 28                         Venetoclax  CHEMBL3137309   GO_0042493
# 29                          Ceritinib  CHEMBL2403108   GO_0042493
# 30                               Ar42           None   GO_0042493
# 31  Mek Inhibitor +/- Mtor Inhibitors           None   GO_0042493
# 32                    Ezh2 Inhibitors           None   GO_0042493
# 33                     Pak Inhibitors           None   GO_0042493
# 34                          Nilotinib   CHEMBL255863   GO_0042493
# 35                        Pramlintide  CHEMBL2103758   GO_0042493
# 36  Cdk4/6 Inhibitor + Mek Inhibitors           None   GO_0042493
# 37                    Mtor Inhibitors           None   GO_0042493
# 38                        Vemurafenib  CHEMBL1229517   GO_0042493
# 39            Pi3k Pathway Inhibitors           None   GO_0042493
# 40                    Hdac Inhibitors           None   GO_0042493
# 41                    Parp Inhibitors           None   GO_0042493
# 42                             Lee011           None   GO_0042493
# 43                    Aurk Inhibitors           None   GO_0042493
# 44                          Ponatinib  CHEMBL1171837   GO_0042493
# 45                         Lorlatinib  CHEMBL3286830   GO_0042493
# 46                       Daunorubicin      CHEMBL178   GO_0042493
# 47                         Everolimus  CHEMBL1908360   GO_0042493
# 48                        Vinblastine      CHEMBL159   GO_0042493
# 49                 Pan-raf Inhibitors           None   GO_0042493
#
#                          diseaseFromSource       confidence  \
# 0               Non-small cell lung cancer      Case report
# 1                 Malignant rhabdoid tumor      Case report
# 2                Colorectal adenocarcinoma      Late trials
# 3                           Lung carcinoma     Pre-clinical
# 4                           Lung carcinoma     Pre-clinical
# 5                Colorectal adenocarcinoma      Case report
# 6                                   Glioma     Early trials
# 7                        Ovarian carcinoma     Pre-clinical
# 8   Malignant peripheral nerve sheat tumor     Pre-clinical
# 9                Colorectal adenocarcinoma     Pre-clinical
# 10                          Lung carcinoma      Case report
# 11                  Plexiform neurofibroma     Early trials
# 12                         Any cancer type   FDA guidelines
# 13                                  Glioma      Case report
# 14                Chronic myeloid leukemia  NCCN guidelines
# 15                         Medulloblastoma      Case report
# 16                    Pancreatic carcinoma      Case report
# 17            Acute lymphoblastic leukemia     Pre-clinical
# 18                   Breast adenocarcinoma      Late trials
# 19               Colorectal adenocarcinoma     Pre-clinical
# 20                      Cutaneous melanoma     Pre-clinical
# 21               Colorectal adenocarcinoma     Pre-clinical
# 22                      Cutaneous melanoma      Case report
# 23                          Lung carcinoma     Early trials
# 24                      Cutaneous melanoma     Early trials
# 25                       Ovarian carcinoma      Case report
# 26                         Any cancer type     Pre-clinical
# 27                          Lung carcinoma      Case report
# 28            Acute lymphoblastic leukemia     Pre-clinical
# 29               Colorectal adenocarcinoma      Case report
# 30                              Meningioma     Early trials
# 31                  Acute myeloid leukemia     Pre-clinical
# 32                         Any cancer type     Pre-clinical
# 33                      Cutaneous melanoma     Pre-clinical
# 34                Chronic myeloid leukemia   FDA guidelines
# 35                        Thymic carcinoma     Pre-clinical
# 36                      Cutaneous melanoma     Early trials
# 37            Acute lymphoblastic leukemia     Pre-clinical
# 38            Lagerhans cell histiocytosis  NCCN guidelines
# 39                       Bladder carcinoma      Case report
# 40                      Cutaneous melanoma     Pre-clinical
# 41                       Ovarian carcinoma     Pre-clinical
# 42                                Lymphoma     Early trials
# 43                 Prostate adenocarcinoma     Pre-clinical
# 44                Chronic myeloid leukemia   FDA guidelines
# 45                     Lung adenocarcinoma      Case report
# 46                  Acute myeloid leukemia   FDA guidelines
# 47                              Schwannoma     Early trials
# 48                                  Glioma     Early trials
# 49                          Lung carcinoma     Early trials
#
#                                     biomarkerName  \
# 0                                    EGFR (D761Y)
# 1                                SMARCB1 deletion
# 2                              EGFR amplification
# 3                                    NF1 deletion
# 4                                  ERCC1 deletion
# 5                       MAP2K1 oncogenic mutation
# 6                  EGFR inframe deletion (30-336)
# 7                        ERCC6 oncogenic mutation
# 8                                    NF1 deletion
# 9                        ZNRF3 oncogenic mutation
# 10                              EGFR-RAD51 fusion
# 11                         NF1 oncogenic mutation
# 12                      DPYD splice donor variant
# 13                                   NF1 deletion
# 14     ABL1 (T315A,F317L,F317V,F317I,F317C,V299L)
# 15                                    SMO (D473H)
# 16                                 PALB2 deletion
# 17                              JAK1 (S646F;R683)
# 18  PTEN oncogenic mutation + ERBB2 amplification
# 19                       EGFR (S464L,G465R,I491M)
# 20                            GNA11 (Q209L,Q209P)
# 21                              MET amplification
# 22                        NRAS oncogenic mutation
# 23                            ERBB2 (V659E,S310F)
# 24                              KIT amplification
# 25                                   BRAF (V600E)
# 26                         ATR oncogenic mutation
# 27         NF2 deletion + EGFR oncogenic mutation
# 28                                ABL1-BCR fusion
# 29                                     ALK fusion
# 30                         NF2 oncogenic mutation
# 31                        HRAS oncogenic mutation
# 32                       PBRM1 oncogenic mutation
# 33                             PAK1 amplification
# 34                                ABL1-BCR fusion
# 35                                  TP53 deletion
# 36                        NRAS oncogenic mutation
# 37                                   CRLF2 fusion
# 38     BRAF (V600E,V600D,V600K,V600M,V600G,V600R)
# 39                      PIK3CA oncogenic mutation
# 40                                  BAP1 deletion
# 41                                 BRCA1 deletion
# 42                        CDK4 oncogenic mutation
# 43                            AURKA amplification
# 44                                   ABL1 (T315I)
# 45                           ROS1 (S1986Y,S1986F)
# 46                      DNMT3A oncogenic mutation
# 47                         NF2 oncogenic mutation
# 48                         NF1 oncogenic mutation
# 49                        KRAS oncogenic mutation
#
#                         literature  \
# 0                       [19680293]
# 1                             None
# 2             [17664472, 18794099]
# 3                       [24296828]
# 4             [23934192, 23275151]
# 5                       [26030179]
# 6                       [19204207]
# 7                       [25634215]
# 8                       [24373973]
# 9                       [26023187]
# 10                      [27102076]
# 11                      [23099009]
# 12                            None
# 13                      [24634382]
# 14                      [21562040]
# 15            [25759019, 19726788]
# 16                      [21135251]
# 17            [22955920, 18805579]
# 18                      [27091708]
# 19                      [25623215]
# 20                            None
# 21                      [27397505]
# 22                            None
# 23                            None
# 24                      [23775962]
# 25                      [22608338]
# 26                      [23548269]
# 27                      [24813888]
# 28                      [27582059]
# 29  [26933125, 27742657, 26633560]
# 30                            None
# 31            [22507781, 22399013]
# 32                      [26552009]
# 33                      [23535073]
# 34                            None
# 35                      [25409149]
# 36                      [26658964]
# 37                      [22955920]
# 38                      [26287849]
# 39                            None
# 40                      [22038994]
# 41                      [22392482]
# 42                            None
# 43            [22389870, 22302096]
# 44                            None
# 45                      [27401242]
# 46                      [22417203]
# 47                      [24311643]
# 48                            None
# 49                            None
#
#                                                  urls  \
# 0                                                None
# 1   [{'niceName': 'European Society for Medical On...
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12  [{'niceName': 'Food and Drug Administration gu...
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  [{'niceName': 'Clinical Trials', 'url': 'https...
# 21                                               None
# 22  [{'niceName': 'European Society for Medical On...
# 23  [{'niceName': 'American Society of Clinical On...
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30  [{'niceName': 'American Society of Clinical On...
# 31                                               None
# 32                                               None
# 33                                               None
# 34  [{'niceName': 'Food and Drug Administration gu...
# 35                                               None
# 36  [{'niceName': 'Clinical Trials', 'url': 'https...
# 37                                               None
# 38                                               None
# 39  [{'niceName': 'European Society for Medical On...
# 40                                               None
# 41                                               None
# 42  [{'niceName': 'Clinical Trials', 'url': 'https...
# 43                                               None
# 44  [{'niceName': 'Food and Drug Administration gu...
# 45                                               None
# 46                                               None
# 47                                               None
# 48  [{'niceName': 'American Society of Clinical On...
# 49  [{'niceName': 'American Association for Cancer...
#
#                                            biomarkers qualityControls  \
# 0   {'geneExpression': None, 'geneticVariation': [...              []
# 1   {'geneExpression': None, 'geneticVariation': [...              []
# 2   {'geneExpression': None, 'geneticVariation': [...              []
# 3   {'geneExpression': None, 'geneticVariation': [...              []
# 4   {'geneExpression': None, 'geneticVariation': [...              []
# 5   {'geneExpression': None, 'geneticVariation': [...              []
# 6   {'geneExpression': None, 'geneticVariation': [...              []
# 7   {'geneExpression': None, 'geneticVariation': [...              []
# 8   {'geneExpression': None, 'geneticVariation': [...              []
# 9   {'geneExpression': None, 'geneticVariation': [...              []
# 10  {'geneExpression': None, 'geneticVariation': [...              []
# 11  {'geneExpression': None, 'geneticVariation': [...              []
# 12  {'geneExpression': None, 'geneticVariation': [...              []
# 13  {'geneExpression': None, 'geneticVariation': [...              []
# 14  {'geneExpression': None, 'geneticVariation': [...              []
# 15  {'geneExpression': None, 'geneticVariation': [...              []
# 16  {'geneExpression': None, 'geneticVariation': [...              []
# 17  {'geneExpression': None, 'geneticVariation': [...              []
# 18  {'geneExpression': None, 'geneticVariation': [...              []
# 19  {'geneExpression': None, 'geneticVariation': [...              []
# 20  {'geneExpression': None, 'geneticVariation': [...              []
# 21  {'geneExpression': None, 'geneticVariation': [...              []
# 22  {'geneExpression': None, 'geneticVariation': [...              []
# 23  {'geneExpression': None, 'geneticVariation': [...              []
# 24  {'geneExpression': None, 'geneticVariation': [...              []
# 25  {'geneExpression': None, 'geneticVariation': [...              []
# 26  {'geneExpression': None, 'geneticVariation': [...              []
# 27  {'geneExpression': None, 'geneticVariation': [...              []
# 28  {'geneExpression': None, 'geneticVariation': [...              []
# 29  {'geneExpression': None, 'geneticVariation': [...              []
# 30  {'geneExpression': None, 'geneticVariation': [...              []
# 31  {'geneExpression': None, 'geneticVariation': [...              []
# 32  {'geneExpression': None, 'geneticVariation': [...              []
# 33  {'geneExpression': None, 'geneticVariation': [...              []
# 34  {'geneExpression': None, 'geneticVariation': [...              []
# 35  {'geneExpression': None, 'geneticVariation': [...              []
# 36  {'geneExpression': None, 'geneticVariation': [...              []
# 37  {'geneExpression': None, 'geneticVariation': [...              []
# 38  {'geneExpression': None, 'geneticVariation': [...              []
# 39  {'geneExpression': None, 'geneticVariation': [...              []
# 40  {'geneExpression': None, 'geneticVariation': [...              []
# 41  {'geneExpression': None, 'geneticVariation': [...              []
# 42  {'geneExpression': None, 'geneticVariation': [...              []
# 43  {'geneExpression': None, 'geneticVariation': [...              []
# 44  {'geneExpression': None, 'geneticVariation': [...              []
# 45  {'geneExpression': None, 'geneticVariation': [...              []
# 46  {'geneExpression': None, 'geneticVariation': [...              []
# 47  {'geneExpression': None, 'geneticVariation': [...              []
# 48  {'geneExpression': None, 'geneticVariation': [...              []
# 49  {'geneExpression': None, 'geneticVariation': [...              []
#
#         diseaseId         targetId publicationDate evidenceDate  score
# 0     EFO_0003060  ENSG00000146648      2009-08-01   2009-08-01    1.0
# 1     EFO_0005701  ENSG00000099956            None         None    1.0
# 2     EFO_0000365  ENSG00000146648      2007-08-01   2007-08-01    1.0
# 3     EFO_0001071  ENSG00000196712      2013-12-02   2013-12-02    1.0
# 4     EFO_0001071  ENSG00000012061      2012-12-28   2012-12-28    1.0
# 5     EFO_0000365  ENSG00000169032      2015-06-01   2015-06-01    1.0
# 6     EFO_0005543  ENSG00000146648      2009-02-09   2009-02-09    1.0
# 7     EFO_0001075  ENSG00000225830      2015-01-29   2015-01-29    1.0
# 8     EFO_0000760  ENSG00000196712      2013-12-27   2013-12-27    1.0
# 9     EFO_0000365  ENSG00000183579      2015-05-28   2015-05-28    1.0
# 10    EFO_0001071  ENSG00000146648      2016-04-21   2016-04-21    1.0
# 11    EFO_0000658  ENSG00000196712      2012-10-23   2012-10-23    1.0
# 12  MONDO_0004992  ENSG00000188641            None         None    1.0
# 13    EFO_0005543  ENSG00000196712      2014-03-14   2014-03-14    1.0
# 14    EFO_0000339  ENSG00000097007      2011-05-11   2011-05-11    1.0
# 15    EFO_0002939  ENSG00000128602      2009-09-02   2009-09-02    1.0
# 16    EFO_0002618  ENSG00000083093      2010-12-06   2010-12-06    1.0
# 17    EFO_0000220  ENSG00000162434      2008-09-19   2008-09-19    1.0
# 18    EFO_0000304  ENSG00000141736      2016-04-18   2016-04-18    1.0
# 19    EFO_0000365  ENSG00000146648      2015-01-26   2015-01-26    1.0
# 20    EFO_0000389  ENSG00000088256            None         None    1.0
# 21    EFO_0000365  ENSG00000105976      2016-07-07   2016-07-07    1.0
# 22    EFO_0000389  ENSG00000213281            None         None    1.0
# 23    EFO_0001071  ENSG00000141736            None         None    1.0
# 24    EFO_0000389  ENSG00000157404      2013-06-17   2013-06-17    1.0
# 25    EFO_0001075  ENSG00000157764      2012-05-01   2012-05-01    1.0
# 26  MONDO_0004992  ENSG00000175054      2013-04-02   2013-04-02    1.0
# 27    EFO_0001071  ENSG00000186575      2014-05-09   2014-05-09    1.0
# 28    EFO_0000220  ENSG00000097007      2016-08-01   2016-08-01    1.0
# 29    EFO_0000365  ENSG00000171094      2015-12-03   2015-12-03    1.0
# 30  MONDO_0016642  ENSG00000186575            None         None    1.0
# 31    EFO_0000222  ENSG00000174775      2012-03-08   2012-03-08    1.0
# 32  MONDO_0004992  ENSG00000163939      2015-11-09   2015-11-09    1.0
# 33    EFO_0000389  ENSG00000149269      2013-03-27   2013-03-27    1.0
# 34    EFO_0000339  ENSG00000097007            None         None    1.0
# 35    EFO_1000576  ENSG00000141510      2014-11-17   2014-11-17    1.0
# 36    EFO_0000389  ENSG00000213281      2015-12-11   2015-12-11    1.0
# 37    EFO_0000220  ENSG00000292363      2012-09-06   2012-09-06    1.0
# 38    EFO_1000318  ENSG00000157764      2015-08-01   2015-08-01    1.0
# 39  MONDO_0004986  ENSG00000121879            None         None    1.0
# 40    EFO_0000389  ENSG00000163930      2011-10-28   2011-10-28    1.0
# 41    EFO_0001075  ENSG00000012048      2012-07-01   2012-07-01    1.0
# 42    EFO_0000574  ENSG00000135446            None         None    1.0
# 43    EFO_0000673  ENSG00000087586      2011-11-01   2011-11-01    1.0
# 44    EFO_0000339  ENSG00000097007            None         None    1.0
# 45    EFO_0000571  ENSG00000047936      2016-07-11   2016-07-11    1.0
# 46    EFO_0000222  ENSG00000119772      2012-03-14   2012-03-14    1.0
# 47    EFO_0000693  ENSG00000186575      2013-12-04   2013-12-04    1.0
# 48    EFO_0005543  ENSG00000196712            None         None    1.0
# 49    EFO_0001071  ENSG00000133703            None         None    1.0

# %%
# Compare score distributions
print(f"Associations score range: {a_df['score'].min():.2f} to {a_df['score'].max():.2f}")
print(f"Biomarkers score range: {b_df['score'].min():.2f} to {b_df['score'].max():.2f}")

# Are they similar distributions?
print("\nAssociations score stats:")
print(a_df['score'].describe())

print("\nBiomarkers score stats:")
print(b_df['score'].describe())

# How many unique target-disease pairs in each?
print("\nAssociations pairs:", a_df[['targetId', 'diseaseId']].drop_duplicates().shape[0])
print("Biomarkers pairs:", b_df[['targetId', 'diseaseId']].drop_duplicates().shape[0])

# How many overlap?
assoc_pairs = set(a_df[['targetId', 'diseaseId']].apply(tuple, axis=1))
biom_pairs = set(b_df[['targetId', 'diseaseId']].apply(tuple, axis=1))
print("Overlapping pairs:", len(assoc_pairs & biom_pairs))
# Out:
# Associations score range: 0.00 to 0.91
# Biomarkers score range: 1.00 to 1.00
#
# Associations score stats:
# count    4.492971e+06
# mean     6.339187e-02
# std      1.085055e-01
# min      7.902492e-04
# 25%      3.695799e-03
# 50%      2.197744e-02
# 75%      5.335624e-02
# max      9.133829e-01
# Name: score, dtype: float64
#
# Biomarkers score stats:
# count    1301.0
# mean        1.0
# std         0.0
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         1.0
# max         1.0
# Name: score, dtype: float64
#
# Associations pairs: 4492971
# Biomarkers pairs: 469
# Overlapping pairs: 469

# %% [markdown]
# ## Score Column Analysis
#
# The `score` columns in both datasets are **semantically distinct** and cannot be directly compared:
#
# **Associations dataset:**
# - Score represents the aggregated strength of evidence for a direct target-disease association
# - Calculated across all data sources (GWAS, literature, animal models, etc.)
# - Range: 0.01 to 0.83 in our data
# - Interpretation: Higher score = stronger overall evidence linking target to disease
#
# **Biomarkers dataset:**
# - Score is always 1.0 (binary indicator that biomarker evidence exists)
# - Does not provide a meaningful confidence metric
# - The actual evidence quality is captured in the `confidence` column instead (values: "case report", "late trials", "pre-clinical", etc.)
# - Represents strength of evidence for a specific biomarker observation, not the overall target-disease relationship
#
# ## Dataset Relationship
#
# Key findings from overlap analysis:
# - **Associations:** 4,492,971 unique target-disease pairs
# - **Biomarkers:** 469 unique target-disease pairs
# - **Overlap:** All 469 biomarker pairs exist in the associations dataset (100% overlap)
#
# This confirms that the biomarkers dataset is a **focused subset** of associations, providing drug-biomarker enrichment data for cancer-specific target-disease relationships. The biomarkers data represents detailed evidence for a small fraction (~0.01%) of all known target-disease associations.

# %%
# Can one target-disease pair have multiple biomarker records?
biomarker_counts = b_df.groupby(['targetId', 'diseaseId']).size()
print("Biomarker records per target-disease pair:")
print(biomarker_counts.describe())
print("\nMax biomarkers for one pair:", biomarker_counts.max())
# Out:
# Biomarker records per target-disease pair:
# count    469.000000
# mean       2.773987
# std        4.208773
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       42.000000
# dtype: float64
#
# Max biomarkers for one pair: 42

# %% [markdown]
# ## Cardinality Analysis
#
# The relationship between associations and biomarkers is **one-to-many**:
# - Most target-disease pairs (50%) have just 1 biomarker record
# - Mean: 2.77 biomarker records per pair
# - Maximum: 42 records for a single pair
# - Distribution is heavily right-skewed
#
# **Why one-to-many?**
# A single target-disease association can have multiple biomarker evidence items, each documenting different drugs, genetic variants, clinical contexts, or confidence levels.
#
# **Example:** BRCA1-breast cancer (one association) might have separate biomarker records for trastuzumab response, olaparib efficacy, and various clinical trial findings.
#
# **Implication for data model:** Associations and biomarkers should be kept in **separate, related tables** rather than flattened into one denormalized table.
